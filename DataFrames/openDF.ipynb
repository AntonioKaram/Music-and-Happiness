# %%
import pandas as pd
import plotly.express as px

store = pd.HDFStore('store.h5')

df = store['df']


print(df)
# Out:
#     country  year crime education  depression  gdp per cap  avg valence  \
# 0        ae  2018     0         0       4.724       7329.0     0.429012
# 1        ae  2019     0     104.5       4.722       5731.0     0.454716
# 2        ae  2020     0     110.2       4.814       6122.0     0.475540
# 3        ae  2021     0      92.3       4.956       6369.0     0.490852
# 4        ae  2022     0      86.8       5.194       6001.0     0.469834
# ..      ...   ...   ...       ...         ...          ...          ...
# 355      za  2018     0         0       4.724       7329.0     0.429012
# 356      za  2019     0     104.5       4.722       5731.0     0.454716
# 357      za  2020     0     110.2       4.814       6122.0     0.475540
# 358      za  2021     0      92.3       4.956       6369.0     0.490852
# 359      za  2022     0      86.8       5.194       6001.0     0.469834
#
#                                                  top 1  \
# ...
